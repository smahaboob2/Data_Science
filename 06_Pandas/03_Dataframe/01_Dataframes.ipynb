# %% [markdown]
# # Python | Pandas DataFrame

# %%
import IPython
url = 'https://media.geeksforgeeks.org/wp-content/uploads/finallpandas.png'
IPython.display.Image(url, width = 500)

# %% [markdown]
# ### Creating a DataFrame
# ### Dealing with Rows and Columns
# ### Indexing and Selecting Data
# ### Working with Missing Data
# ### Iterating over rows and columns

# %% [markdown]
# # Creating a Pandas DataFrame

# %% [markdown]
# ### Creating a dataframe using List:

# %%
# import pandas as pd
import pandas as pd
 
# list of strings
lst = ['Test1', 'Test2', 'Test3', 'Test4', 'Test5', 'Test6', 'Test7']
 
# Calling DataFrame constructor on list
df = pd.DataFrame(lst)
print(df)
# Out:
#        0
# 0  Test1
# 1  Test2
# 2  Test3
# 3  Test4
# 4  Test5
# 5  Test6
# 6  Test7

# %% [markdown]
# ### Creating DataFrame from dict of ndarray/lists

# %%
# Python code demonstrate creating 
# DataFrame from dict narray / lists 
# By default addresses.
 
import pandas as pd
 
# intialise data of lists.
data = {'Name':['Tom', 'nick', 'krish', 'jack'],
        'Age':[20, 21, 19, 18]}
 
# Create DataFrame
df = pd.DataFrame(data)
 
# Print the output.
print(df)
# Out:
#     Name  Age
# 0    Tom   20
# 1   nick   21
# 2  krish   19
# 3   jack   18

# %% [markdown]
# # Dealing with Rows and Columns

# %% [markdown]
# ### Column Selection

# %%
# Import pandas package
import pandas as pd
 
# Define a dictionary containing employee data
data = {'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'],
        'Age':[27, 24, 22, 32],
        'Address':['Delhi', 'Kanpur', 'Allahabad', 'Kannauj'],
        'Qualification':['Msc', 'MA', 'MCA', 'Phd']}
 
# Convert the dictionary into DataFrame 
df = pd.DataFrame(data)
 
# select two columns
print(df[['Name', 'Qualification']])
# Out:
#      Name Qualification
# 0     Jai           Msc
# 1  Princi            MA
# 2  Gaurav           MCA
# 3    Anuj           Phd

# %% [markdown]
# ### Row Selection

# %%
# importing pandas package
import pandas as pd
 
# making data frame from csv file
data = pd.read_csv("Fortune_10.csv", index_col ="Name")
data
# Out:
#                  ID             Industry  Inception       Revenue  \
# Name
# Lamtone           1          IT Services       2009  $11,757,018
# Stripfind         2   Financial Services       2010  $12,329,371
# Canecorporation   3               Health       2012  $10,597,009
# Mattouch          4          IT Services       2013  $14,026,934
# Techdrill         5               Health       2009  $10,573,990
# Techline          6               Health       2006  $13,898,119
# Cityace           7               Health       2010   $9,254,614
# Kayelectronics    8               Health       2009   $9,451,943
# Ganzlax           9          IT Services       2011  $14,001,180
# Trantraxlax      10  Government Services       2011  $11,088,336
#
#                           Expenses    Profit Growth
# Name
# Lamtone          6,482,465 Dollars   5274553    30%
# Stripfind          916,455 Dollars  11412916    20%
# Canecorporation  7,591,189 Dollars   3005820     7%
# Mattouch         7,429,377 Dollars   6597557     7%
# Techdrill        7,435,363 Dollars   3138627     7%
# Techline         5,470,303 Dollars   8427816     7%
# Cityace          6,249,498 Dollars   3005116    16%
# Kayelectronics   3,878,113 Dollars   5573830     4%
# Ganzlax          3,878,113 Dollars  11901180    18%
# Trantraxlax      5,635,276 Dollars   5453060     7%

# %%
# retrieving row by loc method
first = data.loc["Lamtone"]
second = data.loc["Stripfind"]
 
print(first, "\n\n\n", second)
# Out:
# ID                           1
# Industry           IT Services
# Inception                 2009
# Revenue           $11,757,018
# Expenses     6,482,465 Dollars
# Profit                 5274553
# Growth                     30%
# Name: Lamtone, dtype: object
#
#
#  ID                            2
# Industry     Financial Services
# Inception                  2010
# Revenue            $12,329,371
# Expenses        916,455 Dollars
# Profit                 11412916
# Growth                      20%
# Name: Stripfind, dtype: object

# %% [markdown]
# # Indexing and Selecting Data

# %% [markdown]
# ### Selecting a single columns

# %%
# importing pandas package
import pandas as pd
 
# making data frame from csv file
data = pd.read_csv("Fortune_10.csv", index_col ="Name")
 
# retrieving columns by indexing operator
first = data["Industry"]
print(first)
# Out:
# Name
# Lamtone                    IT Services
# Stripfind           Financial Services
# Canecorporation                 Health
# Mattouch                   IT Services
# Techdrill                       Health
# Techline                        Health
# Cityace                         Health
# Kayelectronics                  Health
# Ganzlax                    IT Services
# Trantraxlax        Government Services
# Name: Industry, dtype: object

# %% [markdown]
# ### Indexing a DataFrame using .loc[ ] :

# %%
# importing pandas package
import pandas as pd
 
# making data frame from csv file
data = pd.read_csv("Fortune_10.csv", index_col ="Name")
 
# retrieving row by loc method
first = data.loc["Lamtone"]
second = data.loc["Stripfind"]
 
 
print(first, "\n\n\n", second)
# Out:
# ID                           1
# Industry           IT Services
# Inception                 2009
# Revenue           $11,757,018
# Expenses     6,482,465 Dollars
# Profit                 5274553
# Growth                     30%
# Name: Lamtone, dtype: object
#
#
#  ID                            2
# Industry     Financial Services
# Inception                  2010
# Revenue            $12,329,371
# Expenses        916,455 Dollars
# Profit                 11412916
# Growth                      20%
# Name: Stripfind, dtype: object

# %% [markdown]
# ### Indexing a DataFrame using .iloc[ ] :

# %%
import pandas as pd
 
# making data frame from csv file
data = pd.read_csv("Fortune_10.csv", index_col ="Name")
 
 
# retrieving rows by iloc method 
row2 = data.iloc[3] 
print(row2)
# Out:
# ID                           4
# Industry           IT Services
# Inception                 2013
# Revenue           $14,026,934
# Expenses     7,429,377 Dollars
# Profit                 6597557
# Growth                      7%
# Name: Mattouch, dtype: object

# %% [markdown]
# # Working with Missing Data

# %% [markdown]
# ### Checking for missing values using isnull() and notnull() :

# %%
# importing pandas as pd
import pandas as pd
 
# importing numpy as np
import numpy as np
 
# dictionary of lists
dict = {'First Score':[100, 90, np.nan, 95],
        'Second Score': [30, 45, 56, np.nan],
        'Third Score':[np.nan, 40, 80, 98]}
 
# creating a dataframe from list
df = pd.DataFrame(dict)
 
# using isnull() function  
df.isnull()
# Out:
#    First Score  Second Score  Third Score
# 0        False         False         True
# 1        False         False        False
# 2         True         False        False
# 3        False          True        False

# %% [markdown]
# ### Filling missing values using fillna(), replace() and interpolate() :

# %%
# importing pandas as pd
import pandas as pd
 
# importing numpy as np
import numpy as np
 
# dictionary of lists
dict = {'First Score':[100, 90, np.nan, 95],
        'Second Score': [30, 45, 56, np.nan],
        'Third Score':[np.nan, 40, 80, 98]}
 
# creating a dataframe from dictionary
df = pd.DataFrame(dict)
 
# filling missing value using fillna()  
df.fillna(0)
# Out:
#    First Score  Second Score  Third Score
# 0        100.0          30.0          0.0
# 1         90.0          45.0         40.0
# 2          0.0          56.0         80.0
# 3         95.0           0.0         98.0

# %% [markdown]
# ### Dropping missing values using dropna() :

# %%
# importing pandas as pd
import pandas as pd
 
# importing numpy as np
import numpy as np
 
# dictionary of lists
dict = {'First Score':[100, 90, np.nan, 95],
        'Second Score': [30, np.nan, 45, 56],
        'Third Score':[52, 40, 80, 98],
        'Fourth Score':[np.nan, np.nan, np.nan, 65]}
 
# creating a dataframe from dictionary
df = pd.DataFrame(dict)
   
df
# Out:
#    First Score  Second Score  Third Score  Fourth Score
# 0        100.0          30.0           52           NaN
# 1         90.0           NaN           40           NaN
# 2          NaN          45.0           80           NaN
# 3         95.0          56.0           98          65.0

# %%
# importing pandas as pd
import pandas as pd
 
# importing numpy as np
import numpy as np
 
# dictionary of lists
dict = {'First Score':[100, 90, np.nan, 95],
        'Second Score': [30, np.nan, 45, 56],
        'Third Score':[52, 40, 80, 98],
        'Fourth Score':[np.nan, np.nan, np.nan, 65]}
 
# creating a dataframe from dictionary
df = pd.DataFrame(dict)
 
# using dropna() function  
df.dropna()
# Out:
#    First Score  Second Score  Third Score  Fourth Score
# 3         95.0          56.0           98          65.0

# %% [markdown]
# # Iterating over rows and columns

# %% [markdown]
# ### Iterating over rows :

# %%
# importing pandas as pd
import pandas as pd
  
# dictionary of lists
dict = {'name':["aparna", "pankaj", "sudhir", "Geeku"],
        'degree': ["MBA", "BCA", "M.Tech", "MBA"],
        'score':[90, 40, 80, 98]}
 
# creating a dataframe from a dictionary 
df = pd.DataFrame(dict)
 
print(df)
# Out:
#      name  degree  score
# 0  aparna     MBA     90
# 1  pankaj     BCA     40
# 2  sudhir  M.Tech     80
# 3   Geeku     MBA     98

# %%
# importing pandas as pd
import pandas as pd
  
# dictionary of lists
dict = {'name':["aparna", "pankaj", "sudhir", "Geeku"],
        'degree': ["MBA", "BCA", "M.Tech", "MBA"],
        'score':[90, 40, 80, 98]}
 
# creating a dataframe from a dictionary 
df = pd.DataFrame(dict)
 
# iterating over rows using iterrows() function 
for i, j in df.iterrows():
    print(i, j)
    print()
# Out:
# 0 name      aparna
# degree       MBA
# score         90
# Name: 0, dtype: object
#
# 1 name      pankaj
# degree       BCA
# score         40
# Name: 1, dtype: object
#
# 2 name      sudhir
# degree    M.Tech
# score         80
# Name: 2, dtype: object
#
# 3 name      Geeku
# degree      MBA
# score        98
# Name: 3, dtype: object

# %% [markdown]
# ### Iterating over Columns :

# %%
# importing pandas as pd
import pandas as pd
   
# dictionary of lists
dict = {'name':["aparna", "pankaj", "sudhir", "Geeku"],
        'degree': ["MBA", "BCA", "M.Tech", "MBA"],
        'score':[90, 40, 80, 98]}
  
# creating a dataframe from a dictionary 
df = pd.DataFrame(dict)
 
print(df)
# Out:
#      name  degree  score
# 0  aparna     MBA     90
# 1  pankaj     BCA     40
# 2  sudhir  M.Tech     80
# 3   Geeku     MBA     98

# %%
# creating a list of dataframe columns
columns = list(df)
 
for i in columns:
 
    # printing the third element of the column
    print (df[i][2])
# Out:
# sudhir
# M.Tech
# 80
